# %% [markdown]
# <a href="https://colab.research.google.com/github/lukasfebri015/Semester2/blob/main/tugas_logikainformatika_lukasfl.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy as sp

# %%
df_penerima = pd.read_csv('/content/tugas-logikainformatika.csv')
df_penerima.head(40)
# Out:
#                  p;q;~p;~b;pv~q;~p^~q;(pv~q)^(~p^~q);
# 0             TRUE;TRUE;FALSE;FALSE;TRUE;FALSE;FALSE;
# 1             TRUE;FALSE;FALSE;TRUE;TRUE;FALSE;FALSE;
# 2            FALSE;TRUE;TRUE;FALSE;FALSE;FALSE;FALSE;
# 3               FALSE;FALSE;TRUE;TRUE;TRUE;TRUE;TRUE;
# 4                          NO 4 JAWABAN DIATAS;;;;;;;
# 5                                             ;;;;;;;
# 6                                             ;;;;;;;
# 7                                         NO 1;;;;;;;
# 8                      p;q;p^q;~(p^q);~(p^q)v(p^q);;;
# 9                       TRUE;TRUE;FALSE;FALSE;TRUE;;;
# 10                      TRUE;FALSE;FALSE;TRUE;TRUE;;;
# 11                     FALSE;TRUE;TRUE;FALSE;FALSE;;;
# 12                      FALSE;FALSE;TRUE;TRUE;TRUE;;;
# 13                                            ;;;;;;;
# 14                                        NO 2;;;;;;;
# 15                    p;q;~r;pvq;r^q;p^q;(pvq)^(r^q);
# ...
